# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
csvs = os.listdir()

for csv in csvs:
  if csv[:-3] == 'csv':
    pd.read_csv(csv)

# %%
df = pd.read_csv(r'D:\U\Proyecto ruido y vibraciones\csv\crv1.csv',sep=';', decimal=',')

df
# Out:
#               Tiempo   67Hz   71Hz   75Hz   79Hz   84Hz   89Hz   94Hz  100Hz  \
# 0    01-01-2000 0:07  22.98  24.47  25.51  20.39  28.19  28.73  28.09  29.67
# 1    01-01-2000 0:07  22.53  31.85  28.47  12.60  23.38  29.31  33.01  39.61
# 2    01-01-2000 0:07  17.18  26.56  19.29  14.68  27.50  23.00  26.02  32.12
# 3    01-01-2000 0:07  26.53  28.84  29.98  22.54  28.66  33.12  36.92  37.38
# 4    01-01-2000 0:07  16.46  35.48  32.25  16.36  23.10  30.90  30.56  35.18
# ..               ...    ...    ...    ...    ...    ...    ...    ...    ...
# 559  01-01-2000 0:12  26.17  26.80  28.22  18.87  22.49  21.01  35.36  37.36
# 560  01-01-2000 0:12  28.32  36.68  34.91  15.99  20.29  28.96  33.89  31.09
# 561  01-01-2000 0:12  23.52  28.02  31.53  13.26  20.39  26.40  22.74  31.06
# 562  01-01-2000 0:12  16.78  30.49  27.06  15.58  24.51  22.43  32.98  30.67
# 563  01-01-2000 0:12  25.74  23.51  30.84  22.07  32.97  31.39  31.73  38.03
#
# ...

# %%
df = df.apply(lambda x: 10**(x/10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\danie\.conda\envs\ruido_industrial\Lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File c:\Users\danie\.conda\envs\ruido_industrial\Lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\danie\.conda\envs\ruido_industrial\Lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# ...

# %%
n = len(df)
niveles = []
for freq in df:
  niveles.append(10*np.log10((1/n)*np.sum(df[freq])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\U\Proyecto ruido y vibraciones\NivelesBandas.ipynb Celda 5 line 4
#       <a href='vscode-notebook-cell:/d%3A/U/Proyecto%20ruido%20y%20vibraciones/NivelesBandas.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> niveles = []
#       <a href='vscode-notebook-cell:/d%3A/U/Proyecto%20ruido%20y%20vibraciones/NivelesBandas.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> for freq in df:
# ----> <a href='vscode-notebook-cell:/d%3A/U/Proyecto%20ruido%20y%20vibraciones/NivelesBandas.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>   niveles.append(10*np.log10((1/n)*np.sum(df[freq])))
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
niveles
# Out:
# [2.1141260713035854, 3.114126071303585, 4.114126071303585]

# %%
df.to_csv('niveles.csv')
